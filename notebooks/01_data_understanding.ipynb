# %% [markdown]
# <a href="https://colab.research.google.com/github/Alymbaek/home-credit-risk-ml/blob/main/notebooks/01_data_understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Home Credit Risk ML — Data Understanding
#
# ## Purpose
#
# This notebook explores the structure of the Home Credit Default Risk dataset.
#
# ## Goals
#
# - Identify all available tables
# - Understand the target variable
# - Determine relationships between tables
# - Inspect identifiers and row granularity
# - Detect initial data quality issues
# - Define a leakage-safe validation strategy

# %%
# %pip install -q kaggle==2.2.2
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 4.5 MB/s eta 0:00:00

# %%
import os

from google.colab import userdata


kaggle_token = userdata.get("KAGGLE_API_TOKEN")

if not kaggle_token:
    raise RuntimeError(
        "KAGGLE_API_TOKEN is missing. Add it to Colab Secrets."
    )

os.environ["KAGGLE_API_TOKEN"] = kaggle_token
del kaggle_token

print("Kaggle token loaded successfully.")
# Out:
# Kaggle token loaded successfully.

# %%
# !kaggle --version
# Out:
# Kaggle CLI 2.2.2

# %%
# !kaggle competitions files -c home-credit-default-risk
# Out:
# name                                      size  creationDate
# ----------------------------------  ----------  --------------------------
# HomeCredit_columns_description.csv       37383  2019-12-11 02:55:39.025000
# POS_CASH_balance.csv                 392703158  2019-12-11 02:55:51.293000
# application_test.csv                  26567651  2019-12-11 02:55:45.469000
# application_train.csv                166133370  2019-12-11 02:55:46.979000
# bureau.csv                           170016717  2019-12-11 02:55:47.023000
# bureau_balance.csv                   375592889  2019-12-11 02:55:52.848000
# credit_card_balance.csv              424582605  2019-12-11 02:55:52.357000
# installments_payments.csv            723118349  2019-12-11 02:56:09.108000
# previous_application.csv             404973293  2019-12-11 02:55:55.841000
# sample_submission.csv                   536202  2019-12-11 02:55:48.980000
